# %% [markdown]
# # Electric Vehicle Charging Station & Range Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the electric vehicle charging station data
evcs_data = pd.read_csv(r'C:\Users\Danish\Downloads\Charging_Station.csv')

# %%
# Print the first 5 rows of the dataset
evcs_data.head()
# Out:
#    _id  no region                                            address  \
# 0    1   1   NDMC  Prithviraj Market, Rabindra Nagar, New Delhi- ...
# 1    2   2   NDMC  Prithviraj Market, Rabindra Nagar, New Delhi- ...
# 2    3   3   NDMC  Outside RWA Park, Jor Bagh Market, Jor Bagh Co...
# 3    4   4   NDMC  Opposite Dory Pharmacy, Khanna Market, Aliganj...
# 4    5   5   NDMC  Opposite Goel Opticals, Khanna Market, Aliganj...
#
#                                           aux addres   latitude  longitude  \
# 0  Electric Vehicle Charger, Prithviraj Market, R...  28.600725  77.226252
# 1  Electric Vehicle Charger, Prithviraj Market, R...  28.600725  77.226252
# 2  Electric Vehicle Charger, Outside RWA Park, Jo...  28.588303  77.217697
# 3  Electric Vehicle Charger, Opposite Dory Pharma...  28.582654  77.220087
# 4  Electric Vehicle Charger, Opposite Goel Optica...  28.584485  77.220316
#
#      type  power       service  State
# 0  DC-001  15 kW  Self Service  Delhi
# 1  DC-001  15 kW  Self Service  Delhi
# 2  DC-001  15 kW  Self Service  Delhi
# 3  DC-001  15 kW  Self Service  Delhi
# 4  DC-001  15 kW  Self Service  Delhi

# %%
# Check the shape of the dataset
print('Shape of Dataset:', evcs_data.shape)
# Out:
# Shape of Dataset: (202, 11)

# %%
# Check for missing values
print('Missing Values:')
print(evcs_data.isnull().sum())
# Out:
# Missing Values:
# _id           0
# no            0
# region        0
# address       0
# aux addres    0
# latitude      0
# longitude     0
# type          0
# power         0
# service       0
# State         0
# dtype: int64

# %%
# Print summary statistics for numeric columns
print('Summary Statistics:')
evcs_data.describe()
# Out:
# Summary Statistics:
#               _id          no    latitude   longitude
# count  202.000000  202.000000  202.000000  202.000000
# mean   101.500000  101.500000   25.960987   78.418002
# std     58.456537   58.456537    5.616108    3.097664
# min      1.000000    1.000000    8.481051   76.277781
# 25%     51.250000   51.250000   28.535516   77.212996
# 50%    101.500000  101.500000   28.580286   77.226252
# 75%    151.750000  151.750000   28.617783   77.375216
# max    202.000000  202.000000   28.642892   88.509064

# %%
# Visualize the distribution of charging station types
plt.hist(evcs_data['type'])
plt.xlabel('type')
plt.ylabel('Count')
plt.show()

# %%
# Visualize the distribution of charging station states

# Extract the column of interest and count the occurrences of each value
column_of_interest = 'State'
value_counts = evcs_data[column_of_interest].value_counts()

plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')

# Add title
plt.title('State Distribution')

# Show the plot
plt.show()

# %%
# Visualize the distribution of charging station power ratings
plt.hist(evcs_data['power'])
plt.xlabel('power')
plt.ylabel('Count')
plt.show()

# %%
# Visualize the distribution of charging station power ratings
# Extract the column of interest and count the occurrences of each value
column_of_interest = 'service'
value_counts = evcs_data[column_of_interest].value_counts()

# Create the donut chart
fig, ax = plt.subplots()
ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
ax.axis('equal')
circle = plt.Circle((0,0), 0.7, color='White')
ax.add_artist(circle)

# Add title
plt.title('Service Type')

# Show the plot
plt.show()

# %% [markdown]
# # 2nd Dataset

# %%
#Reading csv file
df = pd.read_csv(r'C:\Users\Danish\Downloads\Ev Datset.csv')

# %%
df.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0       460              70.0              161             940         Yes
# 1       270              45.0              167             250         Yes
# 2       400              75.0              181             620         Yes
# 3       360              74.0              206             560         Yes
# 4       170              28.5              168             190         Yes
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro
# 0        AWD  Type 2 CCS      Sedan       D      5      55480
# 1        RWD  Type 2 CCS  Hatchback       C      5      30000
# 2        AWD  Type 2 CCS   Liftback       D      5      56440
# 3        RWD  Type 2 CCS        SUV       D      5      68040
# 4        RWD  Type 2 CCS  Hatchback       B      4      32997

# %%
df.isnull().sum()
# Out:
# Brand               0
# Model               0
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# PriceEuro           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Battery_Pack Kwh', 'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge',
#        'PowerTrain', 'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro',
#        'FullName'],
#       dtype='object')

# %%
#Adding one more column for futher analysis
#Dividing dataframe based on price for easier analysis

df['FullName'] = df['Brand'] + '-' + df['Model']
df_1 = df.loc[df['PriceEuro'] <= 50000]
df_2 = df.loc[df['PriceEuro'] > 50000]
t1 = 'Less than 50,000 Euros' 
t2 = 'More than 50,000 Euros'

# %% [markdown]
# ## Count Plots

# %%
#count plot for powertrain

def power_train(dataframe): 
    sns.countplot(x= dataframe['PowerTrain'])
    plt.title('Count Plot of Powertrain', fontsize = 20)
    plt.xlabel('Power Train', fontsize = 15)
    plt.ylabel('Count', fontsize = 15)

# %% [markdown]
# ## Count plot for body style

# %%
def bodystyle(dataframe):
    plt.figure(figsize=(10, 5))
    sns.countplot(x= 'BodyStyle', data= dataframe, hue='PowerTrain')
    plt.title('Count plot of Body Style', fontsize= 20)
    plt.xlabel('Body Style', fontsize= 15)
    plt.ylabel('Count', fontsize= 15)
    plt.show()

# %% [markdown]
# ## Bar Graphs
#
# ### Function to plot range of vehicles

# %%
def range(dataframe, price):
  plt.figure(figsize=(20,5))
  sns.set_theme(style="whitegrid")
  sns.barplot('FullName', 'Range_Km' , data = dataframe, hue = dataframe['PowerTrain'])
  plt.title('''Range(Km) of EV's costing {} '''.format(price), fontsize = 20)
  plt.ylabel('Range (Km)', fontsize= 15)
  plt.xlabel('Model', fontsize= 15)
  plt.xticks(rotation = 90)
  plt.show()

# %% [markdown]
# ### Range vs Battery Pack

# %%
def range_batterypack(dataframe, text):
  fig = plt.figure(figsize=(20,5))
  ax1 = plt.subplot()
  ax1.bar(dataframe['FullName'], dataframe['Range_Km'],label= 'Range (Km)', color= 'steelblue')
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1.105))
  ax2 = ax1.twinx()
  ax2.scatter(dataframe['FullName'], dataframe['Battery_Pack Kwh'], label= 'Battery Pack', color = 'black')
  plt.title('''RANGE (Km) vs BATTERY PACK CAPACITY (KwH) of EV's costing {}'''.format(text), fontsize= 20)
  ax1.set_xlabel('Models', size = 20)
  ax1.set_ylabel('Range (Km)', color = 'steelblue', size = 20)
  ax2.set_ylabel('Battery Pack Capacity (Kwh)', color= 'black', size= 20)
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1))
  ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')
  plt.show()

# %% [markdown]
# ### Acceleration (0 - 100Km/Hr)

# %%
def acc(dataframe, text):
  plt.figure(figsize=(20,5))
  sns.set_theme(style="whitegrid")
  sns.barplot('FullName', 'AccelSec', data = dataframe, hue = dataframe['PowerTrain'])
  plt.title('''Acceleration 0-100 Km  of EV's costing {}'''.format(text), fontsize= 20)
  plt.ylabel('Acceleration (seconds)')
  plt.xlabel('Model')
  plt.xticks(rotation = 90)
  plt.show()

# %% [markdown]
# ### Range vs Price

# %%
def range_price(dataframe, text):
  fig = plt.figure(figsize=(20,5))
  ax1 = plt.subplot()
  ax1.bar(dataframe['FullName'], dataframe['Range_Km'],label= 'Range (Km)', color= 'steelblue')
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1.1))
  ax2 = ax1.twinx()
  ax2.scatter(dataframe['FullName'], dataframe['PriceEuro'], label= 'Price', color = 'black')
  plt.title('''RANGE (Km) vs PRICE (Euros)of EV's costing {}'''.format(text), fontsize= 20)
  ax1.set_xlabel('Models', size = 20)
  ax1.set_ylabel('Range (Km)', color = 'steelblue', size = 20)
  ax2.set_ylabel('Price (Euros)', color= 'black', size= 20)
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1))
  ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')
  plt.show()

# %% [markdown]
# ### Range vs Efficiency

# %%
def range_efficiency(dataframe, text):
  fig = plt.figure(figsize=(20,5))
  ax1 = plt.subplot()
  ax1.bar(dataframe['FullName'], dataframe['Range_Km'],label= 'Range (Km)', color= 'darkseagreen')
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1.1))
  ax2 = ax1.twinx()
  ax2.scatter(dataframe['FullName'], dataframe['Efficiency_WhKm'], label= 'Price', color = 'black')
  plt.title('''RANGE (Km) vs Efficiency (Wh/km)of EV's costing {}'''.format(text), fontsize= 20)
  ax1.set_xlabel('Models', size = 20)
  ax1.set_ylabel('Range (Km)', color = 'darkseagreen', size = 20)
  ax2.set_ylabel('Efficiency (Wh/Km)', color= 'black', size= 20)
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1))
  ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')
  plt.show()

# %% [markdown]
# ### Fast charging data

# %%
def fastcharge(dataframe, price):
  plt.figure(figsize=(20,5))
  sns.set_theme(style="whitegrid")
  sns.barplot('FullName', 'FastCharge_KmH' , data = dataframe, color = 'lightslategrey')
  plt.title('''Fast Charging of EV's costing {} '''.format(price), fontsize = 20)
  plt.ylabel('Charging Capacity (kmH)', fontsize= 15)
  plt.xlabel('Model', fontsize= 15)
  plt.xticks(rotation = 90)
  plt.show()

# %% [markdown]
# ### Data Visualization

# %%
# Count Plots
power_train(evcs_data1)
bodystyle(evcs_data1)

# %%
# Bar Graphs
range(df_1, t1)
range(df_2, t2)
# Out:
# C:\Users\Danish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Danish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
range_batterypack(df_1, t1)
range_batterypack(df_2, t2)
# Out:
# C:\Users\Danish\AppData\Local\Temp\ipykernel_17268\3518130838.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')
# C:\Users\Danish\AppData\Local\Temp\ipykernel_17268\3518130838.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')

# %%
# Acceleration
acc(df_1, t1)
acc(df_2, t2)
# Out:
# C:\Users\Danish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Danish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# price vs acceleration
range_price(df_1, t1)
range_price(df_2, t2)
# Out:
# C:\Users\Danish\AppData\Local\Temp\ipykernel_17268\2603447573.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')
# C:\Users\Danish\AppData\Local\Temp\ipykernel_17268\2603447573.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')

# %%
# range vs efficiency
range_efficiency(df_1, t1)
range_efficiency(df_2, t2)
# Out:
# C:\Users\Danish\AppData\Local\Temp\ipykernel_17268\2146329053.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')
# C:\Users\Danish\AppData\Local\Temp\ipykernel_17268\2146329053.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['FullName'], rotation = 'vertical')

# %%
# Fast charge Data
fastcharge(df_1, t1)
fastcharge(df_2, t2)
# Out:
# C:\Users\Danish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Danish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Answering some basic questions

# %% [markdown]
# ### Which vehicle has max range (km) under 50,000 Euros?

# %%
pd.set_option('display.max_columns', None)
top_range_1 = df_1.sort_values(by= 'Range_Km', ascending= False)
print(top_range_1[['FullName', 'Range_Km', 'Battery_Pack Kwh' ,'PriceEuro', 'RapidCharge']])
# Out:
#                              FullName  Range_Km  Battery_Pack Kwh  PriceEuro  \
# 62                 Nissan-Ariya 87kWh       440              87.0      50000
# 15              Volkswagen-ID.3 Pro S       440              77.0      40936
# 37                      CUPRA-el-Born       425              77.0      45000
# 25                    Volkswagen-ID.4       420              77.0      45000
# 53                  Skoda-Enyaq iV 80       420              77.0      40000
# 12       Hyundai-Kona Electric 64 kWh       400              64.0      40795
# 71                 Skoda-Enyaq iV 80X       400              77.0      45000
# 88                 Skoda-Enyaq iV vRS       400              77.0      47500
# 86      Tesla-Cybertruck Single Motor       390             100.0      45000
# 31                  Kia-e-Niro 64 kWh       370              64.0      38105
# 45                 Kia-E -Soul 64 kWh       365              64.0      36837
# 83         Ford-Mustang Mach-E SR RWD       360              88.0      46900
# 26                Volkswagen-ID.3 Pro       350              58.0      33000
# 39                       Mercedes-EQA       350              66.5      45000
# 80                Volkswagen-ID.3 1st       340              58.0      38987
# 94    Volkswagen-ID.3 Pro Performance       340              58.0      35575
# 49                          Aiways-U5       335              63.0      36057
# 46                      Opel-Ampera-e       335              58.0      41906
# 97                 Nissan-Ariya 63kWh       330              63.0      45000
# 35                     Nissan-Leaf e+       325              56.0      37237
# 99         Nissan-Ariya e-4ORCE 63kWh       325              63.0      50000
# 89                  Skoda-Enyaq iV 60       320              58.0      37500
# 32              Renault-Zoe ZE50 R110       315              52.0      31184
# 38              Renault-Zoe ZE50 R135       310              52.0      33133
# 8   Tesla-Model 3 Standard Range Plus       310              50.0      46380
# 22                  Skoda-Enyaq iV 50       290              52.0      35000
# 7                       Peugeot-e-208       275              45.0      29682
# 20                       Opel-Corsa-e       275              45.0      29146
# 1                Volkswagen-ID.3 Pure       270              45.0      30000
# 36                      Lexus-UX 300e       270              50.0      50000
# 41       Hyundai-Kona Electric 39 kWh       255              39.0      33971
# 60              Renault-Zoe ZE40 R110       255              41.0      29234
# 52                       Opel-Mokka-e       255              45.0      35000
# 93              Fiat-500e Convertible       250              23.8      37900
# 58                       Citroen-e-C4       250              45.0      40000
# 56             DS-3 Crossback E-Tense       250              45.0      37422
# 85                Fiat-500e Hatchback       250              37.3      34900
# 29                 Peugeot-e-2008 SUV       250              45.0      34361
# 14             Hyundai-IONIQ Electric       250              38.3      34459
# 28                      BMW-i3 120 Ah       235              37.9      38017
# 75                  Kia-e-Niro 39 kWh       235              39.0      34400
# 95                  Kia-e-Soul 39 kWh       230              39.0      33133
# 70                     BMW-i3s 120 Ah       230              37.9      41526
# 74                          Sono-Sion       225              35.0      25500
# 18                           MG-ZS EV       220              42.5      30000
# 11                        Nissan-Leaf       220              36.0      29234
# 44                  SEAT-Mii Electric       195              32.3      20129
# 43                   Skoda-CITIGOe iV       195              36.8      24534
# 17                   Volkswagen-e-Up!       195              36.8      21421
# 6                   Volkswagen-e-Golf       190              35.8      31900
# 66              Nissan-e-NV200 Evalia       190              38.0      33246
# 19                     Mini-Cooper SE       185              28.9      31681
# 34                        Mazda-MX-30       180              30.0      32646
# 55                    Honda-e Advance       170              28.5      35921
# 4                             Honda-e       170              28.5      32997
# 68          Renault-Kangoo Maxi ZE 33       160              31.0      38000
# 57                  Renault-Twingo ZE       130              21.3      24790
# 82              Smart-EQ fortwo coupe       100              16.7      21387
# 77                   Smart-EQ forfour        95              16.7      22030
# 91             Smart-EQ fortwo cabrio        95              16.7      24565
#
#    RapidCharge
# 62         Yes
# 15         Yes
# 37         Yes
# 25         Yes
# 53         Yes
# 12         Yes
# 71         Yes
# 88         Yes
# 86         Yes
# 31         Yes
# 45         Yes
# 83         Yes
# 26         Yes
# 39         Yes
# 80         Yes
# 94         Yes
# 49         Yes
# 46         Yes
# 97         Yes
# 35         Yes
# 99         Yes
# 89         Yes
# 32         Yes
# 38         Yes
# 8          Yes
# 22         Yes
# 7          Yes
# 20         Yes
# 1          Yes
# 36         Yes
# 41         Yes
# 60         Yes
# 52         Yes
# 93         Yes
# 58         Yes
# 56         Yes
# 85         Yes
# 29         Yes
# 14         Yes
# 28         Yes
# 75         Yes
# 95         Yes
# 70         Yes
# 74         Yes
# 18         Yes
# 11         Yes
# 44         Yes
# 43         Yes
# 17         Yes
# 6          Yes
# 66         Yes
# 19         Yes
# 34         Yes
# 55         Yes
# 4          Yes
# 68          No
# 57          No
# 82          No
# 77          No
# 91          No

# %% [markdown]
# ### Number of vehicles produced by each brand

# %%
companies = df.groupby('Brand').count()
print(companies['Model'].sort_values(ascending = False))
# Out:
# Brand
# Tesla         13
# Audi           9
# Nissan         8
# Volkswagen     8
# Skoda          6
# Porsche        5
# Renault        5
# Kia            4
# BMW            4
# Ford           4
# Smart          3
# Mercedes       3
# Opel           3
# Hyundai        3
# Byton          3
# Peugeot        2
# Honda          2
# Fiat           2
# SEAT           1
# Sono           1
# Polestar       1
# Aiways         1
# MG             1
# Mini           1
# Mazda          1
# Lucid          1
# Lightyear      1
# Lexus          1
# Jaguar         1
# DS             1
# Citroen        1
# CUPRA          1
# Volvo          1
# Name: Model, dtype: int64

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ### Range of vehicle is proportional to Battery Pack Capacity
# ### Price of vehicle is proportional battery pack capacity
# ### EV's which cost less have higher acceleration(0-100 Km/Hr) time in order to maximize range
# ### High performance EV's have lower efficiency
